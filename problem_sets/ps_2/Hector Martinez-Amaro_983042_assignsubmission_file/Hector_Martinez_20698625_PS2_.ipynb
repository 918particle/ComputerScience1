# %% [markdown]
# Exercise #1

# %%
students = [
("Aaliyah", 4),
("Ben", 1),
("Camila", 3),
("Diego", 5),
("Elena", 2),
("Felix", 0),
("Grace", 3),
("Hector", 4),
("Isabel", 1),
("Jamal", 5),
("Keira", 0),
("Luis", 2)
]

algebra = ["Algebra", []]
trigonometry = [
"Trigonometry", []
]
calculus = ["Calculus", []]

math_courses = (
algebra,
trigonometry,
calculus
)


for student in students:
    name = student[0]
    score = student[1]

    if score >= 4:
        calculus[1].append(name)
    elif score >= 2:
        trigonometry[1].append(name)
    else:
        algebra[1].append(name)



print(calculus)
print(trigonometry)
print(algebra)
# Out:
# ['Calculus', ['Aaliyah', 'Diego', 'Hector', 'Jamal']]
# ['Trigonometry', ['Camila', 'Elena', 'Grace', 'Luis']]
# ['Algebra', ['Ben', 'Felix', 'Isabel', 'Keira']]

# %% [markdown]
# Exercise #2

# %%
students = [
("Aaliyah", 4),
("Ben", 1),
("Camila", 3),
("Diego", 5),
("Elena", 2),
("Felix", 0),
("Grace", 3),
("Hector", 4),
("Isabel", 1),
("Jamal", 5),
("Keira", 0),
("Luis", 2)
]

algebra = ["Algebra", []]
trigonometry = [
"Trigonometry", []
]
calculus = ["Calculus", []]

math_courses = (
algebra,
trigonometry,
calculus
)

i = 0
while i < 12:
    name = students[i][0]
    score = students[i][1]
    if score >= 4:
        calculus[1].append(name)
    elif score >= 2:
        trigonometry[1].append(name)
    else:
        algebra[1].append(name)

    i = i + 1

print(calculus)
print(trigonometry)
print(algebra)
# Out:
# ['Calculus', ['Aaliyah', 'Diego', 'Hector', 'Jamal']]
# ['Trigonometry', ['Camila', 'Elena', 'Grace', 'Luis']]
# ['Algebra', ['Ben', 'Felix', 'Isabel', 'Keira']]

# %% [markdown]
# Exercise #3

# %%
students = []

algebra = ["Algebra", []]
trigonometry = [
"Trigonometry", []
]
calculus = ["Calculus", []]

math_courses = (
algebra,
trigonometry,
calculus
)

i = 0
while i < 10:
    name = input("Student name: ")
    score = int(input("Math score: "))
    if score >= 4:
        calculus[1].append(name)
    elif score >= 2:
        trigonometry[1].append(name)
    else:
        algebra[1].append(name)

    i = i + 1
print(" ")
print(" ")
print(" ")
print(calculus)
print(trigonometry)
print(algebra)
# Out:
# Student name: John
# Math score: 1
# Student name: Matt
# Math score: 2
# Student name: Nay
# Math score: 3
# Student name: Ida
# Math score: 4
# Student name: Jay
# Math score: 5
# Student name: Too
# Math score: 1
# Student name: Ney
# Math score: 2
# Student name: Joo
# Math score: 3
# Student name: joer
# Math score: 4
# Student name: adf
# Math score: 5
# ['Calculus', ['Ida', 'Jay', 'joer', 'adf']]
# ['Trigonometry', ['Matt', 'Nay', 'Ney', 'Joo']]
# ['Algebra', ['John', 'Too']]

# %%
students = [
    ("Aaliyah", 4),
    ("Ben", 4),
    ("Camila", 3),
    ("Diego", 5),
    ("Elena", 2),
    ("Felix", 0),
    ("Grace", 3),
    ("Hector", 4),
    ("Isabel", 1),
    ("Jamal", 5),
    ("Keira", 0),
    ("Luis", 2)
]

algebra = ["Algebra", []]

trigonometry = [
    "Trigonometry", []
]

calculus = ["Calculus", []]

math_courses = (
    algebra,
    trigonometry,
    calculus
)

for student in students:
    name = student[0]
    score = student[1]

    if score == 0 or score == 1:
        algebra[1].append(name)
    elif score == 2 or score == 3:
        trigonometry[1].append(name)
    else:
        calculus[1].append(name)

print(math_courses)

print(math_courses[0])
print(math_courses[1])
print(math_courses[2])
# Out:
# (['Algebra', ['Felix', 'Isabel', 'Keira']], ['Trigonometry', ['Camila', 'Elena', 'Grace', 'Luis']], ['Calculus', ['Aaliyah', 'Ben', 'Diego', 'Hector', 'Jamal']])
# ['Algebra', ['Felix', 'Isabel', 'Keira']]
# ['Trigonometry', ['Camila', 'Elena', 'Grace', 'Luis']]
# ['Calculus', ['Aaliyah', 'Ben', 'Diego', 'Hector', 'Jamal']]

# %%
students = [
    ("Aaliyah", 4),
    ("Ben", 4),
    ("Camila", 3),
    ("Diego", 5),
    ("Elena", 2),
    ("Felix", 0),
    ("Grace", 3),
    ("Hector", 4),
    ("Isabel", 1),
    ("Jamal", 5),
    ("Keira", 0),
    ("Luis", 2)
]

algebra2 = ["Algebra", []]

trigonometry2 = [
    "Trigonometry", []
]

calculus2 = ["Calculus", []]

math_courses2 = (
    algebra2,
    trigonometry2,
    calculus2
)

i = 0

while i < 12:
    name = students[i][0]
    score = students[i][1]

    if score == 0 or score == 1:
        algebra2[1].append(name)
    elif score == 2 or score == 3:
        trigonometry2[1].append(name)
    else:
        calculus2[1].append(name)

    i = i + 1

print(math_courses2)
# Out:
# (['Algebra', ['Felix', 'Isabel', 'Keira']], ['Trigonometry', ['Camila', 'Elena', 'Grace', 'Luis']], ['Calculus', ['Aaliyah', 'Ben', 'Diego', 'Hector', 'Jamal']])

# %%
students = []

i = 0

while i < 10:
    name = input("Student name: ")
    score = int(input("Math score: "))

    students.append((name, score))

    i = i + 1


algebra = ["Algebra", []]

trigonometry = [
    "Trigonometry", []
]

calculus = ["Calculus", []]

math_courses = (
    algebra,
    trigonometry,
    calculus
)


for student in students:
    name = student[0]
    score = student[1]

    if score == 0 or score == 1:
        algebra[1].append(name)
    elif score == 2 or score == 3:
        trigonometry[1].append(name)
    else:
        calculus[1].append(name)


print("Math Placement Report")

print("Algebra:")
print(algebra[1])

print("Trigonometry:")
print(trigonometry[1])

print("Calculus:")
print(calculus[1])
# Out:
# Student name: Alice
# Math score: 0
# Student name: Bob
# Math score: 1
# Student name: Charlie
# Math score: 3
# Student name: David
# Math score: 3
# Student name: Emma
# Math score: 4
# Student name: Frank
# Math score: 5
# Student name: Grace
# Math score: 0
# Student name: Henry
# Math score: 2
# Student name: Isabel
# Math score: 4
# Student name: Jack
# Math score: 5
# Math Placement Report
# Algebra:
# ['Alice', 'Bob', 'Grace']
# Trigonometry:
# ['Charlie', 'David ', 'Henry']
# Calculus:
# ['Emma', 'Frank', 'Isabel', 'Jack']

# %%
# Problem Set 4: Functions and Modules
# Create patient_data.py and heart_screen.py

# Create patient_data.py
patient_data_code = '''
# Problem Set 4: Functions and Modules
# Exercise 1 and Exercise 2
# patient_data.py

patients = [
    ("Alan Reed", "000-00-0001", 74, "04/12/1952", 70, 218, "M"),
    ("Maria Lopez", "000-00-0002", 76, "09/03/1950", 64, 155, "F"),
    ("Robert Chen", "000-00-0003", 68, "01/19/1958", 72, 225, "M"),
    ("James Hill", "000-00-0004", 82, "11/28/1943", 69, 210, "M"),
    ("Susan Patel", "000-00-0005", 72, "06/14/1954", 65, 205, "F"),
    ("David King", "000-00-0006", 71, "02/07/1955", 71, 195, "M"),
    ("Henry Cole", "000-00-0007", 79, "08/21/1947", 68, 242, "M"),
    ("Linda Grant", "000-00-0008", 66, "12/02/1959", 63, 180, "F")
]


def get_patients():
    """Return all patient records."""
    return patients


def screening_rule(patient):
    """Return True when all three screening conditions are met."""
    age = patient[2]
    weight = patient[5]
    gender = patient[6]

    return gender == "M" and age > 70 and weight > 200


def display_patient(patient):
    """Display the patient's information in a readable format."""
    print("Name:", patient[0])
    print("SSN:", patient[1])
    print("Age:", patient[2])
    print("DoB:", patient[3])
    print("Height:", patient[4], "in")
    print("Weight:", patient[5], "lb")
    print("Gender:", patient[6])
'''

with open("patient_data.py", "w") as file:
    file.write(patient_data_code)


# Create heart_screen.py
heart_screen_code = '''
# Problem Set 4: Functions and Modules
# Exercise 3
# heart_screen.py

import patient_data

patients = patient_data.get_patients()

print("Patients Matching Screening Rule")
print()

for patient in patients:
    if patient_data.screening_rule(patient):
        patient_data.display_patient(patient)
        print("")
'''

with open("heart_screen.py", "w") as file:
    file.write(heart_screen_code)


# Run the screening program
exec(heart_screen_code)
# Out:
# Patients Matching Screening Rule
#
# Name: Alan Reed
# SSN: 000-00-0001
# Age: 74
# DoB: 04/12/1952
# Height: 70 in
# Weight: 218 lb
# Gender: M
#
# Name: James Hill
# SSN: 000-00-0004
# Age: 82
# DoB: 11/28/1943
# Height: 69 in
# Weight: 210 lb
# Gender: M
#
# Name: Henry Cole
# SSN: 000-00-0007
# Age: 79
# DoB: 08/21/1947
# Height: 68 in
# Weight: 242 lb
# Gender: M

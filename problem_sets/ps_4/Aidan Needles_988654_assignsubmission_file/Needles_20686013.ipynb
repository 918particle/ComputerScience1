# %%
# %%writefile patient_data.py
patients = [
("Alan Reed", "000-00-0001", 74,
"04/12/1952", 70, 218, "M"),
("Maria Lopez", "000-00-0002", 76,
"09/03/1950", 64, 155, "F"),
("Robert Chen", "000-00-0003", 68,
"01/19/1958", 72, 225, "M"),
("James Hill", "000-00-0004", 82,
"11/28/1943", 69, 210, "M"),
("Susan Patel", "000-00-0005", 72,
"06/14/1954", 65, 205, "F"),
("David King", "000-00-0006", 71,
"02/07/1955", 71, 195, "M"),
("Henry Cole", "000-00-0007", 79,
"08/21/1947", 68, 242, "M"),
("Linda Grant", "000-00-0008", 66,
"12/02/1959", 63, 180, "F")
]

def get_patients():
  """Return all patient records."""
  return patients

def screening_rule(patient):
  """return patient records for male patients over age 70 and over 200 lbs"""
  age = patient[2]
  weight = patient[5]
  gender = patient[6]
  return gender == "M" and age >70 and weight >200

def display_patient(patient):
  """Prints patient information in a readable format"""
  print(f"Name: {patient[0]}")
  print(f"SSN: {patient[1]}")
  print(f"Age: {patient[2]}")
  print(f"DOB: {patient[3]}")
  print(f"Weight: {patient[4]}")
  print(f"Height: {patient[5]}")
  print(f"Gender: {patient[6]}")
# Out:
# Writing patient_data.py

# %%
import patient_data

patients = patient_data.get_patients()

for patient in patients:
  if patient_data.screening_rule(patient):
    patient_data.display_patient(patient)
    print("")
# Out:
# Name: Alan Reed
# SSN: 000-00-0001
# Age: 74
# DOB: 04/12/1952
# Weight: 70
# Height: 218
# Gender: M
#
# Name: James Hill
# SSN: 000-00-0004
# Age: 82
# DOB: 11/28/1943
# Weight: 69
# Height: 210
# Gender: M
#
# Name: Henry Cole
# SSN: 000-00-0007
# Age: 79
# DOB: 08/21/1947
# Weight: 68
# Height: 242
# Gender: M

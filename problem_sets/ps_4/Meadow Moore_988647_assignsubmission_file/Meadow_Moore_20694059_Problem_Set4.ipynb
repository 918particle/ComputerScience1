# %%
import patient_data

# %%
def get_patients():
    """Return all patient records."""
    return patients

# %%
def screening_rule(patient):
    """Return True if the patient meets all three screening conditions."""
    age = patient[2]
    weight = patient[5]
    gender = patient[6]

    return gender == "M" and age > 70 and weight > 200

# %%
def display_patient(patient):
    """Display the patient's information in a readable format."""
    print("Name:", patient[0])
    print("SSN:", patient[1])
    print("Age:", patient[2])
    print("DoB:", patient[3])
    print("Height:", patient[4], "in")
    print("Weight:", patient[5], "lb")
    print("Gender:", patient[6])

# %%
import patient_data

print("Patients Matching Screening Rule")
for patient in patients:
    if screening_rule(patient):
       display_patient(patient)
       print("")
# Out:
# Patients Matching Screening Rule
# Name: John Doe
# SSN: 123-45-6789
# Age: 75
# DoB: 1948-01-01
# Height: 68 in
# Weight: 210 lb
# Gender: M
#
# Name: Robert White
# SSN: 777-88-9999
# Age: 78
# DoB: 1945-09-05
# Height: 71 in
# Weight: 205 lb
# Gender: M

# %%
import patient_data_py as patient_data
patients = patient_data.get_patients()

# %%
print("Patients Matching Screening Rule")
print("-------------------------------")
print(" ")
for patient in patients:
    patient_data.screening_rule(patient)
    patient_data.display_patient(patient)
    print("")
# Out:
# Patients Matching Screening Rule
# -------------------------------
#
# Name: Alan Reed
# SSN: 000-00-0001
# Age: 74
# DoB: 04/12/1952
# Height: 70
# Weight: 218
# Gender: M
#
#
#
# Name: James Hill
# SSN: 000-00-0004
# Age: 82
# DoB: 11/28/1943
# Height: 69
# Weight: 210
# Gender: M
#
#
#
# Name: Henry Cole
# SSN: 000-00-0007
# Age: 79
# DoB: 08/21/1947
# Height: 68
# Weight: 242
# Gender: M

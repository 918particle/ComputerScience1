# %%
patients = [
("Alan Reed", "000-00-0001", 74,
"04/12/1952", 70, 218, "M"),
("Maria Lopez", "000-00-0002", 76,
"09/03/1950", 64, 155, "F"),
("Robert Chen", "000-00-0003", 68,
"01/19/1958", 72, 225, "M"),
("James Hill", "000-00-0004", 82,
"11/28/1943", 69, 210, "M"),
("Susan Patel", "000-00-0005", 72,
"06/14/1954", 65, 205, "F"),
("David King", "000-00-0006", 71,
"02/07/1955", 71, 195, "M"),
("Henry Cole", "000-00-0007", 79,
"08/21/1947", 68, 242, "M"),
("Linda Grant", "000-00-0008", 66,
"12/02/1959", 63, 180, "F")
]

def get_patients():
  """Return all patient records."""
  return patients

def screening_rule(patient):
  age = patient[2]
  weight = patient[5]
  gender = patient[6]

  if gender == 'M' and weight >= 200 and age >= 70:
    print(f"  Name: {patient[0]}")
    print(f"  SSN: {patient[1]}")
    print(f"  Age: {patient[2]}")
    print(f"  DOB: {patient[3]}")
    print(f"  Height: {patient[4]}")
    print(f"  Weight: {patient[5]}")
    print(f"  Gender: {patient[6]}")
    print("-" * 30)
    return True
  return False

print("--- Running Screening Rule for All Patients --- ", "\n")
for patient_record in patients:
  screening_rule(patient_record)
# Out:
# --- Running Screening Rule for All Patients ---
#
#   Name: Alan Reed
#   SSN: 000-00-0001
#   Age: 74
#   DOB: 04/12/1952
#   Height: 70
#   Weight: 218
#   Gender: M
# ------------------------------
#   Name: James Hill
#   SSN: 000-00-0004
#   Age: 82
#   DOB: 11/28/1943
#   Height: 69
#   Weight: 210
#   Gender: M
# ------------------------------
#   Name: Henry Cole
#   SSN: 000-00-0007
#   Age: 79
#   DOB: 08/21/1947
#   Height: 68
#   Weight: 242
#   Gender: M
# ------------------------------

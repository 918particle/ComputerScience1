# %%
from math import cos
print(0.0,cos(0.0))
print(0.5,cos(0.5))
print(1.0,cos(1.0))
print(1.5,cos(1.5))
print(2.0,cos(2.0))
print(2.5,cos(2.5))
print(3.0,cos(3.0))
print(3.5,cos(3.5))
print(4.0,cos(4.0))
print(4.5,cos(4.5))
# Out:
# 0.0 1.0
# 0.5 0.8775825618903728
# 1.0 0.5403023058681398
# 1.5 0.0707372016677029
# 2.0 -0.4161468365471424
# 2.5 -0.8011436155469337
# 3.0 -0.9899924966004454
# 3.5 -0.9364566872907963
# 4.0 -0.6536436208636119
# 4.5 -0.2107957994307797

# %% [markdown]
# Does the shape of your graph resemble the cosine
# function that you expect? Identify approximately
# where the function first crosses zero.
#
# Yes, it should have the characteristics wave-like shape of the cosine function.
# By looking at the results, the function first crosses zero around 1.6.

# %% [markdown]
# ![Screenshot 2026-08-25 at 14.34.43.png](data:image/png;base64,...)

# %%
name = input("Student name: ")

cs_grade = input("Computer Science 1 grade: ")
calculus_grade = input("Calculus I grade: ")
physics_grade = input("General Physics I grade: ")
english_grade = input("English Composition grade: ")
seminar_grade = input("First-Year Seminar grade: ")

print()
print("Report Card")
print("Student:", name)
print()
print(f"Computer Science 1:............ {cs_grade}")
print(f"Calculus I:.................... {calculus_grade}")
print(f"General Physics I:............. {physics_grade}")
print(f"English Composition:........... {english_grade}")
print(f"First-Year Seminar:............ {seminar_grade}")

# %%
cs_students = ["Ada Lovelace", "Alan Turing", "Grace Hopper"]
cs_roster = ["Computer Science 1",["Ada Lovelace","Alan Turing","Grace Hopper"]]
calculus_students = ["Katherine Johnson", "Isaac Newton", "Emmy Noether"]
calculus_roster = ["Calculus 1", ["Katherine Johnson", "Isaac Newton", "Emmy Noether"]]
physics_students = ["Marie Curie", "Albert Einstein", "Richard Feynman"]
physics_roster = ["Physics 1", ["Marie Curie", "Albert Einstein", "Richard Feynman"]]
class_rosters = (cs_roster, calculus_roster, physics_roster)
print(class_rosters)
# Out:
# (['Computer Science 1', ['Ada Lovelace', 'Alan Turing', 'Grace Hopper']], ['Calculus 1', ['Katherine Johnson', 'Isaac Newton', 'Emmy Noether']], ['Physics 1', ['Marie Curie', 'Albert Einstein', 'Richard Feynman']])

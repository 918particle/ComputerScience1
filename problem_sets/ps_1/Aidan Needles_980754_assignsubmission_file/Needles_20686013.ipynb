# %%
from math import cos
x=0.0
print(x, cos(x))
x+=.5
print(x, cos(x))
x+=.5
print(x, cos(x))
x+=.5
print(x, cos(x))
x+=.5
print(x, cos(x))
x+=.5
print(x, cos(x))
x+=.5
print(x, cos(x))
x+=.5
print(x, cos(x))
x+=.5
print(x, cos(x))
x+=.5
print(x, cos(x))
# Out:
# 0.0 1.0
# 0.5 0.8775825618903728
# 1.0 0.5403023058681398
# 1.5 0.0707372016677029
# 2.0 -0.4161468365471424
# 2.5 -0.8011436155469337
# 3.0 -0.9899924966004454
# 3.5 -0.9364566872907963
# 4.0 -0.6536436208636119
# 4.5 -0.2107957994307797

# %% [markdown]
# ![Screenshot 2026-08-26 141116.png](data:image/png;base64,...)

# %%
name = input("Student Name: ")
cs_grade = input("Computer Science 1 grade: ")
calc_grade = input("Calculus I grade: ")
phys_grade = input("General Physics I grade: ")
eng_grade = input("English Composition grade: ")
sem_grade = input("First-Year Seminar grade: ")
print("")
print("Report Card")
print(name)
print("")
print("Computer Science 1..........", cs_grade)
print("Calculus I..................", calc_grade)
print("General Physics I...........", phys_grade)
print("English Composition.........", eng_grade)
print("First-Year Seminar..........", sem_grade)
# Out:
# Student Name: Alex
# Computer Science 1 grade: B+
# Calculus I grade: A-
# General Physics I grade: C+
# English Composition grade: B-
# First-Year Seminar grade: C
#
# Report Card
# Alex
#
# Computer Science 1.......... B+
# Calculus I.................. A-
# General Physics I........... C+
# English Composition......... B-
# First-Year Seminar.......... C

# %%
students1=["Ada Lovelace", "Alan Turing", "Grace Hopper"]
students2=["Katherine Johnson", "Isaac Newton", "Emmy Noether"]
students3=["Marie Curie", "ALbert Einstein", "Richard Feynman"]
course1=["Computer Science 1", students1]
course2=["Calculus I", students2]
course3=["General Physics I", students3]
class_rosters=(course1, course2, course3)
print(class_rosters)
# Out:
# (['Computer Science 1', ['Ada Lovelace', 'Alan Turing', 'Grace Hopper']], ['Calculus I', ['Katherine Johnson', 'Isaac Newton', 'Emmy Noether']], ['General Physics I', ['Marie Curie', 'ALbert Einstein', 'Richard Feynman']])

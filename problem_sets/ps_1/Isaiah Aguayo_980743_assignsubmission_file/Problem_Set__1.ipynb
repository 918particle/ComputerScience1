# %%
from math import cos

print(0.0, cos(0.0))
print(0.5, cos(0.5))
print(1.0, cos(1.0))
print(1.5, cos(1.5))
print(2.0, cos(2.0))
print(2.5, cos(2.5))
print(3.0, cos(3.0))
print(3.5, cos(3.5))
print(4.0, cos(4.0))
print(4.5, cos(4.5))

name = input("Student name: ")

cs_grade = input("Computer Science 1 grade: ")
calc_grade = input("Calculus 1 grade: ")
physics_grade = input("General Physics 1 grade: ")
english_grade = input("English Composition grade: ")
seminar_grade = input("First- Year Seminar grade: ")

print()
print("Report Card")
print("Student: ", name)
print()
print("Computer Science 1......." + cs_grade)
print("Calculus................." + calc_grade)
print("General Physics.........." + physics_grade)
print("English Composition......" + english_grade)
print("First-Year Seminar......." + seminar_grade)

cs_students = (
    "Ada Lovelace",
    "Alan Turing",
    "Grace Hopper"
)

calc_students = (
    "Katherine Johnson",
    "Isaac Newton",
    "Emmy Noether"
)

physics_students = (
    "Matie Curie",
    "Albert Einstein",
    "Richard Feynman"
)

cs_roster = (
    "Computer Science 1",
    cs_students
)

calc_roster = (
    "Calculus 1",
    calc_students
)
physics_roster = (
    "General Physics 1",
    physics_students
)

class_rosters = (
    cs_roster,
    calc_roster,
    physics_roster
)

print(class_rosters)
# Out:
# 0.0 1.0
# 0.5 0.8775825618903728
# 1.0 0.5403023058681398
# 1.5 0.0707372016677029
# 2.0 -0.4161468365471424
# 2.5 -0.8011436155469337
# 3.0 -0.9899924966004454
# 3.5 -0.9364566872907963
# 4.0 -0.6536436208636119
# 4.5 -0.2107957994307797
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_540/2959920110.py in <cell line: 0>()
#      12 print(4.5, cos(4.5))
#      13
# ---> 14 name = input("Student name: ")
#      15
#      16 cs_grade = input("Computer Science 1 grade: ")
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

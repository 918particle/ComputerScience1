# %%
import math

# %%
x=0
print(x, math.cos(x))
x=x+0.5
print(x, math.cos(x))
x=x+0.5
print(x, math.cos(x))
x=x+0.5
print(x, math.cos(x))
x=x+0.5
print(x, math.cos(x))
x=x+0.5
print(x, math.cos(x))
x=x+0.5
print(x, math.cos(x))
x=x+0.5
print(x, math.cos(x))
x=x+0.5
print(x, math.cos(x))
x=x+0.5
print(x, math.cos(x))
# Out:
# 0 1.0
# 0.5 0.8775825618903728
# 1.0 0.5403023058681398
# 1.5 0.0707372016677029
# 2.0 -0.4161468365471424
# 2.5 -0.8011436155469337
# 3.0 -0.9899924966004454
# 3.5 -0.9364566872907963
# 4.0 -0.6536436208636119
# 4.5 -0.2107957994307797

# %% [markdown]
# ![CS HW.png](data:image/png;base64,...)

# %% [markdown]
# It crosses the y-axis at (0, 1) and it crosses the x-axis somewhere in between (1.5, 0.0707372016677029) and (2.0 -0.4161468365471424) which is what I expected.

# %%
print("What's your name?")
name=input()
print("What's your grade in Computer Science 1", name +"?",)
cs_grade=input()
print("What's your grade in Calculus I", name +"?")
ca_grade=input()
print("What's your grade in General Physics I", name +"?")
ph_grade=input()
print("What's your grade in English Composition", name +"?")
en_grade=input()
print("What's your grade in First-Year Seminar", name +"?")
fi_grade=input()
print(" ")
print("Report Card")
print("Student:", name)
print(" ")
print("Computer Science 1........."+ cs_grade)
print("Calculus I................."+ ca_grade)
print("General Physics I.........."+ ph_grade)
print("English Composition........"+ en_grade)
print("First-Year Seminar........."+ fi_grade)
# Out:
# What's your name?
# Ellen
# What's your grade in Computer Science 1 Ellen?
# C
# What's your grade in Calculus I Ellen?
# D
# What's your grade in General Physics I Ellen?
# E
# What's your grade in English Composition Ellen?
# A
# What's your grade in First-Year Seminar Ellen?
# D
#
# Report Card
# Student: Ellen
#
# Computer Science 1.........C
# Calculus I.................D
# General Physics I..........E
# English Composition........A
# First-Year Seminar.........D

# %% [markdown]
# ![unnamed.jpg](data:image/jpeg;base64,...)

# %%
# saving lists and variables

stu_list=["Ada Lovelace",
          "Alan Turing",
          "Grace Hopper"]

stu_list1=["Katherine Johnson",
           "Isaac Newton",
           "Emmy Noether"]

stu_list2=["Marie Curie",
           "Albert Einstein",
           "Richard Feynman"]

Course1="Computer Science 1"
Course2="Calculus I"
Course3="General Physics I"

 # printing course lists

print(f"{Course1}, {stu_list}")
print(" ")
print(f"{Course2}, {stu_list1}")
print(" ")
print(f"{Course3}, {stu_list2}")
print(" ")

# printing class rosters with tulpe

class_roster=([Course1, stu_list],
 [Course2, stu_list1],
 [Course3, stu_list2])

print(f"\n\t{class_roster[0]},\n\t{class_roster[1]},\n\t{class_roster[2]}")
# Out:
# Computer Science 1, ['Ada Lovelace', 'Alan Turing', 'Grace Hopper']
#
# Calculus I, ['Katherine Johnson', 'Isaac Newton', 'Emmy Noether']
#
# General Physics I, ['Marie Curie', 'Albert Einstein', 'Richard Feynman']
#
#
# 	['Computer Science 1', ['Ada Lovelace', 'Alan Turing', 'Grace Hopper']],
# 	['Calculus I', ['Katherine Johnson', 'Isaac Newton', 'Emmy Noether']],
# 	['General Physics I', ['Marie Curie', 'Albert Einstein', 'Richard Feynman']]

# %%
from math import cos
print(0.0, cos(0.0))
print(0.5, cos(0.5))
print(1.0, cos(1.0))
print(1.5, cos(1.5))
print(2.0, cos(2.0))
print(2.5, cos(2.5))
print(3.5, cos(3.5))
print(4.0, cos(4.0))
print(4.5, cos(4.5))
# Out:
# 0.0 1.0
# 0.5 0.8775825618903728
# 1.0 0.5403023058681398
# 1.5 0.0707372016677029
# 2.0 -0.4161468365471424
# 2.5 -0.8011436155469337
# 3.5 -0.9364566872907963
# 4.0 -0.6536436208636119
# 4.5 -0.2107957994307797

# %%
name = input("Student Name: ")
cs_grade = input("Computer Science 1 grade: ")
calculus_grade = input("Calculus I grade: ")
physics_grade = input("General Physics I grade : ")
english_grade = input("English Composition grade: ")
seminar_grade = input("First-Year Seminar Grade: ")

print("Report Card")
print("Student:", name)
print("Computer Science 1", cs_grade)
print("Calculus I", calculus_grade)
print("General Physics I", physics_grade)
print("English Compostition", english_grade)
print("First-Year Seminar", seminar_grade)

# %%
cs_students = [
    "Ada Lovelace",
    "Alan Turing",
    "Grace Hopper"
]

calculus_students = [
    "Katherine Johnson",
    "Issac Newton",
    "Emmy Noether",
]

physics_students = [
    "Marie Curie",
    "Albert Einstein",
    "Richard Feynman"
]

cs_roster = [

    "Computer Science 1",

    cs_students

]

calculus_roster = [

    "Calculus I",

    calculus_students

]

physics_roster = [

    "General Physics I",

    physics_students

]
class_rosters = (

    cs_roster,

    calculus_roster,

    physics_roster

)

print(class_rosters)
# Out:
# (['Computer Science 1', ['Ada Lovelace', 'Alan Turing', 'Grace Hopper']], ['Calculus I', ['Katherine Johnson', 'Issac Newton', 'Emmy Noether']], ['General Physics I', ['Marie Curie', 'Albert Einstein', 'Richard Feynman']])
